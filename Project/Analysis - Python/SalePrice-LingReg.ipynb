# %%
# Import the required basic libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the test and train csv files

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
#train = pd.DataFrame(train)
#test = pd.DataFrame(test)

# %%
train_df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Check the type after loading
type(train_df)
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#sns.pairplot(data =train)

# %%
## Exploratory Data Analysis

# %%
plt.figure(figsize=(28,8))
sns.heatmap(train_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
plt.figure(figsize=(8,4))

sns.set_style('whitegrid')
sns.distplot(train_df['LotFrontage'].dropna(),kde=False, color='darkred', bins=100)

# %%
trainimpu=pd.DataFrame(train_df)

# %%
trainimpu.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
trainimpu.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
trainimpu = trainimpu.interpolate()

# %%
trainimpu = trainimpu.fillna(method = 'bfill')

# %%
trainimpu = trainimpu.fillna(method = 'ffill')

# %%
trainimpu.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
#                 ..
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# ...

# %%
plt.figure(figsize=(28,8))
sns.heatmap(trainimpu.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
trainimpu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
trainimpu.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2   3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3   4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4   5          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0     Ex  MnPrv        Shed       0
# 1         Lvl    AllPub    ...            0     Ex  MnPrv        Shed       0
# 2         Lvl    AllPub    ...            0     Ex  MnPrv        Shed       0
# 3         Lvl    AllPub    ...            0     Ex  MnPrv        Shed       0
# 4         Lvl    AllPub    ...            0     Ex  MnPrv        Shed       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Training a Linear Regression Model

# %%
# Not used for Linear Regression Model

X = trainimpu[['MSZoning','Street','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
               'HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','ExterQual',
               'ExterCond','Foundation','BsmtQual','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','Heating','HeatingQC',
               'CentralAir','X1stFlrSF','X2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd','Fireplaces','GarageArea','CentralAir',
               'GarageCond','WoodDeckSF','ScreenPorch','Fence',
               'SaleCondition']]

# %%
# Not used for Linear Regression Model

y = trainimpu['SalePrice']

# %%
#Converting Categorical Features

# %%
X.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d2a225ce25ec> in <module>()
# ----> 1 X.info()
#
# NameError: name 'X' is not defined

# %%
#Create dummy variables and remove 1st dummy variable.

mSZoning = pd.get_dummies(trainimpu['MSZoning'], drop_first=True)
street = pd.get_dummies(trainimpu['Street'], drop_first=True)
lotConfig = pd.get_dummies(trainimpu['LotConfig'], drop_first=True)
landSlope = pd.get_dummies(trainimpu['LandSlope'], drop_first=True)
neighborhood = pd.get_dummies(trainimpu['Neighborhood'], drop_first=True)
condition1 = pd.get_dummies(trainimpu['Condition1'], drop_first=True)
condition2 = pd.get_dummies(trainimpu['Condition2'], drop_first=True)
bldgType = pd.get_dummies(trainimpu['BldgType'], drop_first=True)
houseStyle = pd.get_dummies(trainimpu['HouseStyle'], drop_first=True)
exterQual = pd.get_dummies(trainimpu['ExterQual'], drop_first=True)
exterCond = pd.get_dummies(trainimpu['ExterCond'], drop_first=True)
foundation = pd.get_dummies(trainimpu['Foundation'], drop_first=True)
bsmtQual = pd.get_dummies(trainimpu['BsmtQual'], drop_first=True)
bsmtFinType2 = pd.get_dummies(trainimpu['BsmtFinType2'], drop_first=True)
heating = pd.get_dummies(trainimpu['Heating'], drop_first=True)
heatingQC = pd.get_dummies(trainimpu['HeatingQC'], drop_first=True)
centralAir = pd.get_dummies(trainimpu['CentralAir'], drop_first=True)
garageCond = pd.get_dummies(trainimpu['GarageCond'], drop_first=True)
fence = pd.get_dummies(trainimpu['Fence'], drop_first=True)
saleCondition = pd.get_dummies(trainimpu['SaleCondition'], drop_first=True)

# %%
#  Get only the required columns for the Linear Model

train = trainimpu[['MSZoning','Street','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
               'HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','ExterQual',
               'ExterCond','Foundation','BsmtQual','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','Heating','HeatingQC',
               'CentralAir','X1stFlrSF','X2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd','Fireplaces','GarageArea','CentralAir',
               'GarageCond','WoodDeckSF','ScreenPorch','Fence',
               'SaleCondition','SalePrice']]

# %%
train.head()
# Out:
#   MSZoning Street LotConfig LandSlope Neighborhood Condition1 Condition2  \
# 0       RL   Pave    Inside       Gtl      CollgCr       Norm       Norm
# 1       RL   Pave       FR2       Gtl      Veenker      Feedr       Norm
# 2       RL   Pave    Inside       Gtl      CollgCr       Norm       Norm
# 3       RL   Pave    Corner       Gtl      Crawfor       Norm       Norm
# 4       RL   Pave       FR2       Gtl      NoRidge       Norm       Norm
#
#   BldgType HouseStyle  OverallQual    ...      TotRmsAbvGrd  Fireplaces  \
# 0     1Fam     2Story            7    ...                 8           0
# 1     1Fam     1Story            6    ...                 6           1
# 2     1Fam     2Story            7    ...                 6           1
# 3     1Fam     2Story            7    ...                 7           1
# 4     1Fam     2Story            8    ...                 9           1
#
#    GarageArea  CentralAir GarageCond WoodDeckSF ScreenPorch  Fence  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 37 columns):
# MSZoning         1460 non-null object
# Street           1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1460 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1460 non-null object
# BsmtFinType2     1460 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# Heating          1460 non-null object
# ...

# %%
train.drop(['MSZoning','Street','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
               'HouseStyle','ExterQual','ExterCond','Foundation','BsmtQual','BsmtFinType2','BsmtFinSF2','Heating','HeatingQC',
               'CentralAir','X1stFlrSF','X2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd','Fireplaces','GarageArea','CentralAir',
               'GarageCond','Fence','SaleCondition'], axis =1, inplace = True )
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
train.head()
# Out:
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtUnfSF  \
# 0            7            5       2003          2003       196.0        150
# 1            6            8       1976          1976         0.0        284
# 2            7            5       2001          2002       162.0        434
# 3            7            5       1915          1970         0.0        540
# 4            8            5       2000          2000       350.0        490
#
#    WoodDeckSF  ScreenPorch  SalePrice
# 0           0            0     208500
# 1         298            0     181500
# 2           0            0     223500
# 3           0            0     140000
# 4         192            0     250000

# %%
train = pd.concat([train,mSZoning,street,lotConfig,landSlope,neighborhood,condition1,condition2,bldgType,
                      houseStyle,exterQual,exterCond,foundation,bsmtQual,bsmtFinType2,heating,heatingQC,centralAir,
                      garageCond,fence,saleCondition], axis =1)

# %%
train.head()
# Out:
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtUnfSF  \
# 0            7            5       2003          2003       196.0        150
# 1            6            8       1976          1976         0.0        284
# 2            7            5       2001          2002       162.0        434
# 3            7            5       1915          1970         0.0        540
# 4            8            5       2000          2000       350.0        490
#
#    WoodDeckSF  ScreenPorch  SalePrice  FV   ...     Po  TA  GdWo  MnPrv  MnWw  \
# 0           0            0     208500   0   ...      0   1     0      1     0
# 1         298            0     181500   0   ...      0   1     0      1     0
# 2           0            0     223500   0   ...      0   1     0      1     0
# 3           0            0     140000   0   ...      0   1     0      1     0
# 4         192            0     250000   0   ...      0   1     0      1     0
#
# ...

# %%
#Training a Linear Regression Model

# %%
#Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('SalePrice',axis=1), 
                                                    train['SalePrice'], test_size=0.30, 
                                                    random_state=101)

# %%
X_train.shape
# Out:
# (1022, 111)

# %%
y_train.shape
# Out:
# (1022,)

# %%
X_test.shape
# Out:
# (438, 111)

# %%
y_test.shape
# Out:
# (438,)

# %%
y_test.head()
# Out:
# 1054    255000
# 361     145000
# 1282    150500
# 161     412500
# 515     402861
# Name: SalePrice, dtype: int64

# %%
X_test.head()
# Out:
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# 1054            8            5       2002          2002       210.0
# 361             5            5       1940          1982         0.0
# 1282            5            7       1977          2008         0.0
# 161             9            5       2003          2004       664.0
# 515            10            5       2009          2009       305.0
#
#       BsmtUnfSF  WoodDeckSF  ScreenPorch  FV  RH   ...     Po  TA  GdWo  \
# 1054        133         199            0   0   0   ...      0   1     0
# 361         484           0            0   0   0   ...      0   1     0
# 1282        364           0          288   0   0   ...      0   1     1
# 161         556         400            0   0   0   ...      0   1     0
# 515         570         156            0   0   0   ...      0   1     0
#
#       MnPrv  MnWw  AdjLand  Alloca  Family  Normal  Partial
# 1054      1     0        0       0       0       1        0
# ...

# %%
X = train.drop('SalePrice',axis=1)

# %%
y = train['SalePrice']

# %%
X.head()
# Out:
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtUnfSF  \
# 0            7            5       2003          2003       196.0        150
# 1            6            8       1976          1976         0.0        284
# 2            7            5       2001          2002       162.0        434
# 3            7            5       1915          1970         0.0        540
# 4            8            5       2000          2000       350.0        490
#
#    WoodDeckSF  ScreenPorch  FV  RH   ...     Po  TA  GdWo  MnPrv  MnWw  \
# 0           0            0   0   0   ...      0   1     0      1     0
# 1         298            0   0   0   ...      0   1     0      1     0
# 2           0            0   0   0   ...      0   1     0      1     0
# 3           0            0   0   0   ...      0   1     0      1     0
# 4         192            0   0   0   ...      0   1     0      1     0
#
#    AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
# Creating and Training the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
linmodel = lm.fit(X_train,y_train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 112 entries, OverallQual to Partial
# dtypes: float64(1), int64(8), uint8(103)
# memory usage: 249.6 KB

# %%
predictions = linmodel.predict(X_test)

# %%
#Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE :', metrics.mean_absolute_error(y_test,predictions))
print('\n')
print('MSE :', metrics.mean_squared_error(y_test,predictions))
print('\n')
print('RMSE :', np.sqrt(metrics.mean_absolute_error(y_test,predictions)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7aeb70e09054> in <module>()
# ----> 1 print('MAE :', metrics.mean_absolute_error(predictions, y_test))
#       2 print('\n')
#       3 print('MSE :', metrics.mean_squared_error(predictions, y_test))
#       4 print('\n')
#       5 print('RMSE :', np.sqrt(metrics.mean_absolute_error(predictions, y_test)))
#
# NameError: name 'predictions' is not defined

# %%
# Create model for real test...............
X.iloc[:, 0:105]
# Out:
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0               7            5       2003          2003       196.0
# 1               6            8       1976          1976         0.0
# 2               7            5       2001          2002       162.0
# 3               7            5       1915          1970         0.0
# 4               8            5       2000          2000       350.0
# 5               5            5       1993          1995         0.0
# 6               8            5       2004          2005       186.0
# 7               7            6       1973          1973       240.0
# 8               7            5       1931          1950         0.0
# 9               5            6       1939          1950         0.0
# 10              5            5       1965          1965         0.0
# 11              9            5       2005          2006       286.0
# 12              5            6       1962          1962         0.0
# ...

# %%
X = X.iloc[:, 0:105]

# %%
     
model = lm.fit(X,y)

# %%
# Prepare the Real Test Data......................

# %%
testimpu=pd.DataFrame(test_df)

# %%
testimpu.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
plt.figure(figsize=(28,8))
sns.heatmap(testimpu.isnull(), yticklabels=False,cbar=False, cmap = 'viridis' )

# %%
testimpu = testimpu.interpolate()

# %%
testimpu = testimpu.fillna(method='bfill')

# %%
testimpu = testimpu.fillna(method='ffill')

# %%
testimpu.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
#                 ..
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# ...

# %%
plt.figure(figsize=(28,8))
sns.heatmap(testimpu.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
#Create dummy variables and remove 1st dummy variable.

mSZoning = pd.get_dummies(testimpu['MSZoning'], drop_first=True)
street = pd.get_dummies(testimpu['Street'], drop_first=True)
lotConfig = pd.get_dummies(testimpu['LotConfig'], drop_first=True)
landSlope = pd.get_dummies(testimpu['LandSlope'], drop_first=True)
neighborhood = pd.get_dummies(testimpu['Neighborhood'], drop_first=True)
condition1 = pd.get_dummies(testimpu['Condition1'], drop_first=True)
condition2 = pd.get_dummies(testimpu['Condition2'], drop_first=True)
bldgType = pd.get_dummies(testimpu['BldgType'], drop_first=True)
houseStyle = pd.get_dummies(testimpu['HouseStyle'], drop_first=True)
exterQual = pd.get_dummies(testimpu['ExterQual'], drop_first=True)
exterCond = pd.get_dummies(testimpu['ExterCond'], drop_first=True)
foundation = pd.get_dummies(testimpu['Foundation'], drop_first=True)
bsmtQual = pd.get_dummies(testimpu['BsmtQual'], drop_first=True)
bsmtFinType2 = pd.get_dummies(testimpu['BsmtFinType2'], drop_first=True)
heating = pd.get_dummies(testimpu['Heating'], drop_first=True)
heatingQC = pd.get_dummies(testimpu['HeatingQC'], drop_first=True)
centralAir = pd.get_dummies(testimpu['CentralAir'], drop_first=True)
garageCond = pd.get_dummies(testimpu['GarageCond'], drop_first=True)
fence = pd.get_dummies(testimpu['Fence'], drop_first=True)
saleCondition = pd.get_dummies(testimpu['SaleCondition'], drop_first=True)

# %%
#  Get only the required columns used in the Linear Model

test = testimpu[['MSZoning','Street','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
               'HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','ExterQual',
               'ExterCond','Foundation','BsmtQual','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','Heating','HeatingQC',
               'CentralAir','X1stFlrSF','X2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd','Fireplaces','GarageArea','CentralAir',
               'GarageCond','WoodDeckSF','ScreenPorch','Fence',
               'SaleCondition']]

# %%
test.drop(['MSZoning','Street','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType',
               'HouseStyle','ExterQual','ExterCond','Foundation','BsmtQual','BsmtFinType2','BsmtFinSF2','Heating','HeatingQC',
               'CentralAir','X1stFlrSF','X2ndFlrSF','BedroomAbvGr','TotRmsAbvGrd','Fireplaces','GarageArea','CentralAir',
               'GarageCond','Fence','SaleCondition'], axis =1, inplace = True )
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
test.head()
# Out:
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtUnfSF  \
# 0            5            6       1961          1961         0.0      270.0
# 1            6            6       1958          1958       108.0      406.0
# 2            5            5       1997          1998         0.0      137.0
# 3            6            6       1998          1998        20.0      324.0
# 4            8            5       1992          1992         0.0     1017.0
#
#    WoodDeckSF  ScreenPorch
# 0         140          120
# 1         393            0
# 2         212            0
# 3         360            0
# 4           0          144

# %%
test = pd.concat([test,mSZoning,street,lotConfig,landSlope,neighborhood,condition1,condition2,bldgType,
                      houseStyle,exterQual,exterCond,foundation,bsmtQual,bsmtFinType2,heating,heatingQC,centralAir,
                      garageCond,fence,saleCondition], axis =1)

# %%
test.head()
# Out:
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtUnfSF  \
# 0            5            6       1961          1961         0.0      270.0
# 1            6            6       1958          1958       108.0      406.0
# 2            5            5       1997          1998         0.0      137.0
# 3            6            6       1998          1998        20.0      324.0
# 4            8            5       1992          1992         0.0     1017.0
#
#    WoodDeckSF  ScreenPorch  FV  RH   ...     Po  TA  GdWo  MnPrv  MnWw  \
# 0         140          120   0   1   ...      0   1     0      1     0
# 1         393            0   0   0   ...      0   1     0      1     0
# 2         212            0   0   0   ...      0   1     0      1     0
# 3         360            0   0   0   ...      0   1     0      0     0
# 4           0          144   0   0   ...      0   1     0      0     0
#
#    AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
test.info()
#train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 105 entries, OverallQual to Partial
# dtypes: float64(2), int64(6), uint8(97)
# memory usage: 229.5 KB

# %%
test[test['OverallQual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtUnfSF, WoodDeckSF, ScreenPorch, FV, RH, RL, RM, Pave, CulDSac, FR2, FR3, Inside, Mod, Sev, Blueste, BrDale, BrkSide, ClearCr, CollgCr, Crawfor, Edwards, Gilbert, IDOTRR, MeadowV, Mitchel, NAmes, NPkVill, NWAmes, NoRidge, NridgHt, OldTown, SWISU, Sawyer, SawyerW, Somerst, StoneBr, Timber, Veenker, Feedr, Norm, PosA, PosN, RRAe, RRAn, RRNe, RRNn, Feedr, Norm, PosA, PosN, 2fmCon, Duplex, Twnhs, TwnhsE, 1.5Unf, 1Story, 2.5Unf, 2Story, SFoyer, SLvl, Fa, Gd, TA, Fa, Gd, Po, TA, CBlock, PConc, Slab, Stone, Wood, Fa, Gd, TA, BLQ, GLQ, LwQ, Rec, Unf, GasW, Grav, Wall, Fa, Gd, Po, TA, Y, Fa, Gd, Po, TA, GdWo, MnPrv, MnWw, ...]
# Index: []
#
# [0 rows x 105 columns]

# %%
# test = test.interpolate()
# testimpu = testimpu.fillna(method='bfill')

# %%
plt.figure(figsize=(50,15))
sns.heatmap(test.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
test.isnull().sum()
# Out:
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# MasVnrArea      0
# BsmtUnfSF       0
# WoodDeckSF      0
# ScreenPorch     0
# FV              0
# RH              0
# RL              0
# RM              0
# Pave            0
# CulDSac         0
# FR2             0
# FR3             0
# Inside          0
# Mod             0
# Sev             0
# Blueste         0
# BrDale          0
# BrkSide         0
# ClearCr         0
# CollgCr         0
# Crawfor         0
# Edwards         0
# Gilbert         0
# IDOTRR          0
# MeadowV         0
# Mitchel         0
#                ..
# Stone           0
# Wood            0
# Fa              0
# Gd              0
# TA              0
# BLQ             0
# GLQ             0
# LwQ             0
# Rec             0
# Unf             0
# GasW            0
# Grav            0
# Wall            0
# Fa              0
# Gd              0
# Po              0
# TA              0
# Y               0
# Fa              0
# ...

# %%
len(test)
# Out:
# 1459

# %%
predictions = model.predict(test)

# %%
predictions
# Out:
# array([  68610.51476852,  138889.93081323,  132144.85433118, ...,
#         132874.27659928,  125961.19707447,  195748.00518438])

# %%
len(predictions)
# Out:
# 1459

# %%
#output = pd.DataFrame(test_df['Id'])
output = pd.DataFrame(test_df['Id'])

# %%
len(output)
type(output)
# Out:
# pandas.core.frame.DataFrame

# %%
output =  pd.concat([output, pd.DataFrame(predictions)], axis = 1)

# %%
output.columns = ['Id', 'SalePrice']

# %%
output.head()
# Out:
#      Id      SalePrice
# 0  1461   68610.514769
# 1  1462  138889.930813
# 2  1463  132144.854331
# 3  1464  188032.599652
# 4  1465  253092.585078

# %%
output.to_csv('pred1.csv', ',', index=False)
